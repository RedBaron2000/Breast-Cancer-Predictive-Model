# %%
#1 Reduce the pixel size of images
#2 Convert images to gray scale
#3 possibly increase contrast
#4 hopefull randomize images for training and testing have good mix of both positive and negative amounts

# %%
matplotlib.image
Pillow
OpenCV

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# load an image through matplotlib.image module

img = mpimg.imread(r"C:\Users\asaqu\Breast Cancer Detection Model\Sorted Data\Positive\8863_idx5_x1001_y801_class1.png")

# %%
img.shape
# Out:
# (50, 50, 3)

# %%
print(img)
# Out:
# [[[0.81960785 0.39607844 0.5294118 ]
#   [0.80784315 0.3882353  0.5568628 ]
#   [0.7607843  0.40392157 0.5568628 ]
#   ...
#   [0.8117647  0.35686275 0.49803922]
#   [0.827451   0.40784314 0.5529412 ]
#   [0.8039216  0.41568628 0.5647059 ]]
#
#  [[0.8352941  0.44705883 0.5647059 ]
#   [0.8235294  0.53333336 0.6666667 ]
#   [0.81960785 0.39607844 0.54901963]
#   ...
#   [0.85882354 0.48235294 0.6156863 ]
#   [0.84705883 0.49411765 0.6392157 ]
#   [0.80784315 0.38039216 0.53333336]]
#
#  [[0.81960785 0.39607844 0.53333336]
#   [0.83137256 0.35686275 0.47843137]
#   [0.80784315 0.38039216 0.49803922]
#   ...
#   [0.8666667  0.4862745  0.627451  ]
#   [0.85490197 0.4392157  0.5764706 ]
#   [0.80784315 0.32941177 0.4745098 ]]
#
#  ...
#
#  [[0.5764706  0.36862746 0.5372549 ]
#   [0.58431375 0.34509805 0.5294118 ]
#   [0.44705883 0.27450982 0.4745098 ]
#   ...
#   [0.7294118  0.38039216 0.54901963]
#   [0.73333335 0.48235294 0.6156863 ]
#   [0.6745098  0.4745098  0.61960787]]
#
# ...

# %%
img_plot = plt.imshow(img)

# %% [markdown]
# ## Resizing Image

# %%
from PIL import Image

# %%
img = Image.open(r"C:\Users\asaqu\Breast Cancer Detection Model\Sorted Data\Positive\8863_idx5_x1001_y801_class1.png")

# %%
img_resized = img.resize((30,30))

# %%
plt.imshow(img_resized)

# %%
img_resized.save()
# Out:
# <PIL.Image.Image image mode=RGB size=30x30 at 0x272A5C45DC0>

# %%
# Convert RGB to Grayscale w/ OpenCV

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\asaqu\Breast Cancer Detection Model\Sorted Data\Positive\8863_idx5_x1001_y801_class1.png")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (50, 50, 3)

# %%
grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
grayscale_img.shape
# Out:
# (50, 50)

# %%
cv2.imshow('Grayscale Image', grayscale_img)
cv2.waitKey(0)
# Out:
# -1

# %%
#save image

cv2.imwrite(filepath, grayscale_image)
